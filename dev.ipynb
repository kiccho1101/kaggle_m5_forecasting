# %%
import pandas as pd
import numpy as np
from kaggle_m5_forecasting import RawData
from thunderbolt import Thunderbolt
tb = Thunderbolt("./resource")
# data: pd.DataFrame = tb.get_data("MakeData")
raw: RawData = tb.get_data("LoadRawData")
data = tb.get_data("MakeData")

# %%
data = data.set_index("id")

# %%
import seaborn as sns
idx = "HOBBIES_1_003_CA_1_validation"
data.loc[idx, "sales"].plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_orig_and_cutoff(i):
    idx = raw.sales_train_validation.loc[i, "id"]
    print(i, idx)
    raw.sales_train_validation.loc[i, "d_1":"d_1913"].plot()
    plt.show()
    data.loc[idx, "sales"].plot()
    data.loc[idx, "sales"].rolling(7).mean().plot()
    data.loc[idx, "sales"].rolling(30).mean().plot()
    plt.show()
    
    data.loc[idx, "sales"].rolling(30).sum().plot()
    plt.show()
    
    
import numpy as np
i = np.random.choice(np.arange(1, len(raw.sales_train_validation)))
plot_orig_and_cutoff(i)
# Out:
# 3844 HOUSEHOLD_1_235_CA_2_validation

# %%
[
    "HOBBIES_1_087_CA_1_validation", 
    "HOBBIES_1_095_CA_1_validation", 
    "FOODS_3_406_TX_3_validation",
    "HOUSEHOLD_1_408_CA_4_validation",
    "HOUSEHOLD_2_239_CA_4_validation",
]
